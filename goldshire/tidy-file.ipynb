# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('csv/stocks-cny.csv', dtype={'Symbol':str})
df1.set_index('Symbol', inplace=True)
#df2 = pd.read_csv('csv/dividends-cny.csv', dtype={'Symbol':str, 'Qty':np.int64})
#df2.set_index('Symbol', inplace=True)
#df2 = pd.read_csv('csv/dz-cny.csv', dtype={'Symbol':str})

# %%
df1
# Out:
#             Name
# Symbol
# 510900     H股ETF
# 150176       H股B
# 159920     恒生ETF
# 600519      贵州茅台
# 600036      招商银行
# 600660      福耀玻璃
# 600886      国投电力
# 000651      格力电器
# 000002       万科A
# 002780      三夫户外
# 603866      桃李面包
# 002785       万里石
# 002081       金螳螂
# 600900      长江电力
# 510300    300ETF
# 600276      恒瑞医药
# 601668      中国建筑
# 000963      华东医药
# 002304      洋河股份
# 600009      上海机场
# 300503      昊志机电
# 600585      海螺水泥
# 601939      建设银行
# 000895      双汇发展
# 600056      中国医药
# 600309      万华化学
# 600059      古越龙山
# 601318      中国平安
# 600919      江苏银行
# 002415      海康威视
# 501021      香港中小
# 601128      常熟银行
# 150210      国企改B
# 600030      中信证券
# 600109      国金证券
# 150201       券商B
# 511990      华宝添益
# 600674      川投能源
# 000001      平安银行
# 000338      潍柴动力
# 002846      英联股份
# 000333      美的集团
# 600597      光明乳业
# 601601      中国太保
# 601166      兴业银行
# 600016      民生银行
# 603316      诚邦股份
# 002714      牧原股份
# 000732      泰禾集团
# 510310  HS300ETF
# 000961      中南建设
